# %% [markdown]
# # Import Libaries

# %%
from selenium import webdriver
import joblib
import numpy as np
import pandas as pd
import csv
from datetime import datetime
import time
import sqlite3

# %% [markdown]
# # Scrap all cars links

# %%
driver = webdriver.Chrome()
links = []

# %%
for page in range(1, 1285):
    print(f'Scraping page : {page}')
    driver.get(f'https://eg.hatla2ee.com/en/car/page/{page}')
    for header in driver.find_elements_by_class_name('newCarListUnit_header'):
        links.append(header.find_element_by_tag_name('a').get_attribute('href'))
# Out:
# Scraping page : 1
# Scraping page : 2
# Scraping page : 3
# Scraping page : 4
# Scraping page : 5
# Scraping page : 6
# Scraping page : 7
# Scraping page : 8
# Scraping page : 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-dd2c227634f0> in <module>
#       3     driver.get(f'https://eg.hatla2ee.com/en/car/page/{page}')
#       4     for header in driver.find_elements_by_class_name('newCarListUnit_header'):
# ----> 5         links.append(header.find_element_by_tag_name('a').get_attribute('href'))
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
# --> 141                 self, name)
#     142         else:
#     143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Anaconda3\envs\tensorflow\lib\http\client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# C:\Anaconda3\envs\tensorflow\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# C:\Anaconda3\envs\tensorflow\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# C:\Anaconda3\envs\tensorflow\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
driver.close()

# %%
links
# Out:
# ['https://eg.hatla2ee.com/en/car/peugeot/3008/4804503',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804046',
#  'https://eg.hatla2ee.com/en/car/jeep/cherokee/4796227',
#  'https://eg.hatla2ee.com/en/car/lada/granta/4787955',
#  'https://eg.hatla2ee.com/en/car/maserati/ghibli/4803273',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-6/4803254',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4802304',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4784469',
#  'https://eg.hatla2ee.com/en/car/byd/f3/4635257',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4599533',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4805270',
#  'https://eg.hatla2ee.com/en/car/kia/sportage/4805279',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4805274',
#  'https://eg.hatla2ee.com/en/car/chevrolet/T-Series/4805267',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4805265',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4805256',
#  'https://eg.hatla2ee.com/en/car/hyundai/veloster/4805244',
#  'https://eg.hatla2ee.com/en/car/nissan/qashqai/4805255',
#  'https://eg.hatla2ee.com/en/car/chevrolet/cruze/4805243',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805240',
#  'https://eg.hatla2ee.com/en/car/hyundai/elantra/4805237',
#  'https://eg.hatla2ee.com/en/car/mercedes/C+300/4805234',
#  'https://eg.hatla2ee.com/en/car/hyundai/IX-35/4805232',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4805231',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4805220',
#  'https://eg.hatla2ee.com/en/car/volvo/s60/4805217',
#  'https://eg.hatla2ee.com/en/car/fiat/132/4805214',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4805211',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/polo/4805208',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4805207',
#  'https://eg.hatla2ee.com/en/car/renault/fluence/4805201',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/jetta/4805199',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805196',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805193',
#  'https://eg.hatla2ee.com/en/car/renault/duster/4805187',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4805186',
#  'https://eg.hatla2ee.com/en/car/toyota/Belta/4805183',
#  'https://eg.hatla2ee.com/en/car/jac/Eagle/4805180',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4805175',
#  'https://eg.hatla2ee.com/en/car/speranza/tiggo/4805174',
#  'https://eg.hatla2ee.com/en/car/bmw/320/4785041',
#  'https://eg.hatla2ee.com/en/car/jeep/cherokee/4782669',
#  'https://eg.hatla2ee.com/en/car/land-rover/Velar/4801716',
#  'https://eg.hatla2ee.com/en/car/chevrolet/pickup/4772037',
#  'https://eg.hatla2ee.com/en/car/kia/picanto/4801426',
#  'https://eg.hatla2ee.com/en/car/kia/Pegas/4761338',
#  'https://eg.hatla2ee.com/en/car/changan/v7/4801079',
#  'https://eg.hatla2ee.com/en/car/porsche/boxster/4800529',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-6/4800406',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4800414',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4805151',
#  'https://eg.hatla2ee.com/en/car/fiat/uno/4805153',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/jetta/4805148',
#  'https://eg.hatla2ee.com/en/car/peugeot/307/4805147',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/tiguan/4805138',
#  'https://eg.hatla2ee.com/en/car/citroen/c-elysee/4805136',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4805135',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-MD/4805132',
#  'https://eg.hatla2ee.com/en/car/bmw/525/4805129',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4805117',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805127',
#  'https://eg.hatla2ee.com/en/car/peugeot/3008/4805126',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804437',
#  'https://eg.hatla2ee.com/en/car/peugeot/301/4805123',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4805114',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805111',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos-2/4805108',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4802699',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4805105',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805102',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4805079',
#  'https://eg.hatla2ee.com/en/car/kia/picanto/4805097',
#  'https://eg.hatla2ee.com/en/car/speranza/tiggo/4805096',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4802706',
#  'https://eg.hatla2ee.com/en/car/renault/clio/4804631',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805085',
#  'https://eg.hatla2ee.com/en/car/fiat/polonez/4805081',
#  'https://eg.hatla2ee.com/en/car/skoda/octavia-combi/4805076',
#  'https://eg.hatla2ee.com/en/car/nissan/juke/4805075',
#  'https://eg.hatla2ee.com/en/car/kia/sorento/4803651',
#  'https://eg.hatla2ee.com/en/car/opel/Crossland/4800424',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4800441',
#  'https://eg.hatla2ee.com/en/car/nissan/urvan/4765079',
#  'https://eg.hatla2ee.com/en/car/skoda/felicia/4785101',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4799442',
#  'https://eg.hatla2ee.com/en/car/renault/sandero-step-way/4798964',
#  'https://eg.hatla2ee.com/en/car/hyundai/Accent-RB/4632422',
#  'https://eg.hatla2ee.com/en/car/renault/Kadjar/4798676',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4798689',
#  'https://eg.hatla2ee.com/en/car/renault/megane/4798705',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4805072',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4805066',
#  'https://eg.hatla2ee.com/en/car/hyundai/verna/4805064',
#  'https://eg.hatla2ee.com/en/car/peugeot/206/4805063',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4805060',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/passat/4805058',
#  'https://eg.hatla2ee.com/en/car/chevrolet/cruze/4802152',
#  'https://eg.hatla2ee.com/en/car/changan/cs-35/4804133',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805046',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4805049',
#  'https://eg.hatla2ee.com/en/car/fiat/127/4805045',
#  'https://eg.hatla2ee.com/en/car/mazda/mazda-3/4805042',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805040',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4804214',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4805034',
#  'https://eg.hatla2ee.com/en/car/chevrolet/pickup/4805031',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4805022',
#  'https://eg.hatla2ee.com/en/car/hyundai/verna/4804395',
#  'https://eg.hatla2ee.com/en/car/land-rover/evoque/4805021',
#  'https://eg.hatla2ee.com/en/car/geely/gelly-x-pandino/4805019',
#  'https://eg.hatla2ee.com/en/car/speranza/a11/4805016',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804430',
#  'https://eg.hatla2ee.com/en/car/emgrand/ex-7/4805015',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4805013',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805009',
#  'https://eg.hatla2ee.com/en/car/speranza/a11/4805006',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4805004',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4805001',
#  'https://eg.hatla2ee.com/en/car/seat/arona/4804997',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804994',
#  'https://eg.hatla2ee.com/en/car/seat/leon/4798713',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4798726',
#  'https://eg.hatla2ee.com/en/car/chevrolet/camaro/4593846',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4798509',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4798486',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4737399',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4737351',
#  'https://eg.hatla2ee.com/en/car/seat/leon/4797127',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4796397',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4795573',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4804991',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4804989',
#  'https://eg.hatla2ee.com/en/car/peugeot/405/4804988',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804976',
#  'https://eg.hatla2ee.com/en/car/moris-garage/MG-HS/4804983',
#  'https://eg.hatla2ee.com/en/car/peugeot/5008/4804980',
#  'https://eg.hatla2ee.com/en/car/hyundai/getz/4804977',
#  'https://eg.hatla2ee.com/en/car/toyota/corona/4804974',
#  'https://eg.hatla2ee.com/en/car/kia/sorento/4804968',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4804965',
#  'https://eg.hatla2ee.com/en/car/geely/geely-x7/4804962',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804961',
#  'https://eg.hatla2ee.com/en/car/kia/sportage/4804958',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-CN7/4804956',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804953',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804950',
#  'https://eg.hatla2ee.com/en/car/hyundai/elantra/4804947',
#  'https://eg.hatla2ee.com/en/car/hyundai/elantra/4804937',
#  'https://eg.hatla2ee.com/en/car/geely/fruits/4804896',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-CN7/4804940',
#  'https://eg.hatla2ee.com/en/car/byd/f3/4804938',
#  'https://eg.hatla2ee.com/en/car/chevrolet/aveo/4804928',
#  'https://eg.hatla2ee.com/en/car/chevrolet/aveo/4804926',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804914',
#  'https://eg.hatla2ee.com/en/car/fiat/shahin/4804907',
#  'https://eg.hatla2ee.com/en/car/audi/a3/4804904',
#  'https://eg.hatla2ee.com/en/car/bmw/x1/4804902',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4804901',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804898',
#  'https://eg.hatla2ee.com/en/car/brilliance/galena/4804877',
#  'https://eg.hatla2ee.com/en/car/chevrolet/camaro/4795089',
#  'https://eg.hatla2ee.com/en/car/fiat/tipo/4795104',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4760453',
#  'https://eg.hatla2ee.com/en/car/opel/astra/4787898',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4733891',
#  'https://eg.hatla2ee.com/en/car/kia/sportage/4791873',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4791704',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4791698',
#  'https://eg.hatla2ee.com/en/car/bmw/520/4791446',
#  'https://eg.hatla2ee.com/en/car/suzuki/swift/4791368',
#  'https://eg.hatla2ee.com/en/car/brilliance/galena/4804877',
#  'https://eg.hatla2ee.com/en/car/renault/clio/4804895',
#  'https://eg.hatla2ee.com/en/car/kia/carnival/4804892',
#  'https://eg.hatla2ee.com/en/car/fiat/dogan/4804889',
#  'https://eg.hatla2ee.com/en/car/toyota/corona/4804886',
#  'https://eg.hatla2ee.com/en/car/bmw/740/4804883',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804880',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos/4804866',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/E-Golf/4804874',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804872',
#  'https://eg.hatla2ee.com/en/car/chevrolet/T-Series/4804869',
#  'https://eg.hatla2ee.com/en/car/bmw/320/4804865',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804863',
#  'https://eg.hatla2ee.com/en/car/fiat/siena/4804860',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804857',
#  'https://eg.hatla2ee.com/en/car/hyundai/matrix/4804856',
#  'https://eg.hatla2ee.com/en/car/skoda/felicia/4804848',
#  'https://eg.hatla2ee.com/en/car/bmw/316/4804844',
#  'https://eg.hatla2ee.com/en/car/fiat/shahin/4804841',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos-2/4804835',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4804833',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804826',
#  'https://eg.hatla2ee.com/en/car/isuzu/dmax/4804832',
#  'https://eg.hatla2ee.com/en/car/skoda/Octavia-A5/4804818',
#  'https://eg.hatla2ee.com/en/car/subaru/xv/4804812',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4804805',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4804802',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804799',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804797',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804793',
#  'https://eg.hatla2ee.com/en/car/nissan/qashqai/4790766',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4789223',
#  'https://eg.hatla2ee.com/en/car/mini/mini-cooper-s/4704969',
#  'https://eg.hatla2ee.com/en/car/lada/2105/4578026',
#  'https://eg.hatla2ee.com/en/car/mercedes/cla-180/4790034',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4787693',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4786383',
#  'https://eg.hatla2ee.com/en/car/opel/astra/4749570',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4786650',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4786653',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804826',
#  'https://eg.hatla2ee.com/en/car/isuzu/dmax/4804832',
#  'https://eg.hatla2ee.com/en/car/skoda/Octavia-A5/4804818',
#  'https://eg.hatla2ee.com/en/car/subaru/xv/4804812',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4804805',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4804802',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804799',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804797',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804793',
#  'https://eg.hatla2ee.com/en/car/hyundai/Accent-RB/4804787',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4804784',
#  'https://eg.hatla2ee.com/en/car/jeep/cherokee/4804781',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4804779',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804773',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804764',
#  'https://eg.hatla2ee.com/en/car/daihatsu/terios/4804761',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4804758',
#  'https://eg.hatla2ee.com/en/car/speranza/tiggo/4804752',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4804755',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804749',
#  'https://eg.hatla2ee.com/en/car/skoda/foreman/4804737',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804736',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4804733',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n200/4804727',
#  'https://eg.hatla2ee.com/en/car/chevrolet/lanos2/4804721',
#  'https://eg.hatla2ee.com/en/car/mazda/mazda-3/4804709',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4804719',
#  'https://eg.hatla2ee.com/en/car/fiat/regata/4804718',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804716',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804715',
#  'https://eg.hatla2ee.com/en/car/nissan/sentra/4782461',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4786664',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4786400',
#  'https://eg.hatla2ee.com/en/car/land-rover/evoque/4785372',
#  'https://eg.hatla2ee.com/en/car/opel/vectra/4784918',
#  'https://eg.hatla2ee.com/en/car/kia/pride/4784526',
#  'https://eg.hatla2ee.com/en/car/toyota/C-HR/4784102',
#  'https://eg.hatla2ee.com/en/car/jeep/grand-Cherokee/4750668',
#  'https://eg.hatla2ee.com/en/car/jaguar/E-pace/4755431',
#  'https://eg.hatla2ee.com/en/car/mercedes/gla/4783779',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/golf/4804712',
#  'https://eg.hatla2ee.com/en/car/daewoo/leganza/4804706',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804703',
#  'https://eg.hatla2ee.com/en/car/peugeot/405/4804701',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4804698',
#  'https://eg.hatla2ee.com/en/car/speranza/a113/4804697',
#  'https://eg.hatla2ee.com/en/car/proton/wira/4804695',
#  'https://eg.hatla2ee.com/en/car/fiat/punto-evo/4804689',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804692',
#  'https://eg.hatla2ee.com/en/car/hyundai/verna/4804691',
#  'https://eg.hatla2ee.com/en/car/jac/S4/4804686',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-AD/4804683',
#  'https://eg.hatla2ee.com/en/car/toyota/C-HR/4804680',
#  'https://eg.hatla2ee.com/en/car/kia/carens/4804679',
#  'https://eg.hatla2ee.com/en/car/opel/astra/4804676',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4804673',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4804670',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804668',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804665',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4804664',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804659',
#  'https://eg.hatla2ee.com/en/car/skoda/felicia/4804649',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804647',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4804644',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4804638',
#  'https://eg.hatla2ee.com/en/car/chevrolet/pickup/4804634',
#  'https://eg.hatla2ee.com/en/car/hyundai/getz/4804628',
#  'https://eg.hatla2ee.com/en/car/renault/sandero/4804622',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804619',
#  'https://eg.hatla2ee.com/en/car/speranza/a516/4804617',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-CN7/4782431',
#  'https://eg.hatla2ee.com/en/car/chery/Tiggo-7/4782416',
#  'https://eg.hatla2ee.com/en/car/suzuki/S-Presso/4782330',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4775066',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4775000',
#  'https://eg.hatla2ee.com/en/car/nissan/sentra/4774944',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-AD/4774929',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4774677',
#  'https://eg.hatla2ee.com/en/car/bmw/316/4774664',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4774649',
#  'https://eg.hatla2ee.com/en/car/toyota/hilux/4804599',
#  'https://eg.hatla2ee.com/en/car/mercedes/c-180/4804581',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4804593',
#  'https://eg.hatla2ee.com/en/car/honda/civic/4804590',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804584',
#  'https://eg.hatla2ee.com/en/car/nissan/pick-up/4804580',
#  'https://eg.hatla2ee.com/en/car/renault/sandero-step-way/4804578',
#  'https://eg.hatla2ee.com/en/car/speranza/a516/4804575',
#  'https://eg.hatla2ee.com/en/car/zotye/SR7/4804572',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4804571',
#  'https://eg.hatla2ee.com/en/car/changan/cs-35/4804569',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4804566',
#  'https://eg.hatla2ee.com/en/car/mazda/323/4804563',
#  'https://eg.hatla2ee.com/en/car/byd/f3/4804550',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804556',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4804547',
#  'https://eg.hatla2ee.com/en/car/jeep/komodo/4804545',
#  'https://eg.hatla2ee.com/en/car/fiat/127/4804530',
#  'https://eg.hatla2ee.com/en/car/geely/CK2/4804542',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4804539',
#  'https://eg.hatla2ee.com/en/car/nissan/qashqai/4804538',
#  'https://eg.hatla2ee.com/en/car/renault/sandero-step-way/4804526',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4804523',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4804388',
#  'https://eg.hatla2ee.com/en/car/peugeot/504/4804518',
#  'https://eg.hatla2ee.com/en/car/speranza/chery-qq/4804517',
#  'https://eg.hatla2ee.com/en/car/subaru/impreza/4802598',
#  'https://eg.hatla2ee.com/en/car/geely/CK2/4804511',
#  'https://eg.hatla2ee.com/en/car/peugeot/3008/4804509',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4804506',
#  'https://eg.hatla2ee.com/en/car/mercedes/b-200/4766102',
#  'https://eg.hatla2ee.com/en/car/nissan/sentra/4765952',
#  'https://eg.hatla2ee.com/en/car/hyundai/Tucson-Turbo/4765967',
#  'https://eg.hatla2ee.com/en/car/chery/Tiggo3/4765989',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4804388',
#  'https://eg.hatla2ee.com/en/car/peugeot/504/4804518',
#  'https://eg.hatla2ee.com/en/car/speranza/chery-qq/4804517',
#  'https://eg.hatla2ee.com/en/car/subaru/impreza/4802598',
#  'https://eg.hatla2ee.com/en/car/geely/CK2/4804511',
#  'https://eg.hatla2ee.com/en/car/peugeot/3008/4804509',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4804506',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804505',
#  'https://eg.hatla2ee.com/en/car/mercedes/200/4802844',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804500',
#  'https://eg.hatla2ee.com/en/car/lada/2105/4804499',
#  'https://eg.hatla2ee.com/en/car/fiat/125/4804497',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804496',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos/4804493',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4803332',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804490',
#  'https://eg.hatla2ee.com/en/car/toyota/echo/4803444',
#  'https://eg.hatla2ee.com/en/car/jeep/liberty/4804485',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4804482']

# %%
len(links)
# Out:
# 343

# %% [markdown]
# # Save links

# %%
joblib.dump(links, 'links.h5')
# Out:
# ['links.h5']

# %% [markdown]
# # Load links

# %%
links = joblib.load('links.h5')
links
# Out:
# ['https://eg.hatla2ee.com/en/car/peugeot/3008/4804503',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804046',
#  'https://eg.hatla2ee.com/en/car/jeep/cherokee/4796227',
#  'https://eg.hatla2ee.com/en/car/lada/granta/4787955',
#  'https://eg.hatla2ee.com/en/car/maserati/ghibli/4803273',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-6/4803254',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4802304',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4784469',
#  'https://eg.hatla2ee.com/en/car/byd/f3/4635257',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4599533',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4805270',
#  'https://eg.hatla2ee.com/en/car/kia/sportage/4805279',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4805274',
#  'https://eg.hatla2ee.com/en/car/chevrolet/T-Series/4805267',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4805265',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4805256',
#  'https://eg.hatla2ee.com/en/car/hyundai/veloster/4805244',
#  'https://eg.hatla2ee.com/en/car/nissan/qashqai/4805255',
#  'https://eg.hatla2ee.com/en/car/chevrolet/cruze/4805243',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805240',
#  'https://eg.hatla2ee.com/en/car/hyundai/elantra/4805237',
#  'https://eg.hatla2ee.com/en/car/mercedes/C+300/4805234',
#  'https://eg.hatla2ee.com/en/car/hyundai/IX-35/4805232',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4805231',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4805220',
#  'https://eg.hatla2ee.com/en/car/volvo/s60/4805217',
#  'https://eg.hatla2ee.com/en/car/fiat/132/4805214',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4805211',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/polo/4805208',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4805207',
#  'https://eg.hatla2ee.com/en/car/renault/fluence/4805201',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/jetta/4805199',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805196',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805193',
#  'https://eg.hatla2ee.com/en/car/renault/duster/4805187',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4805186',
#  'https://eg.hatla2ee.com/en/car/toyota/Belta/4805183',
#  'https://eg.hatla2ee.com/en/car/jac/Eagle/4805180',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4805175',
#  'https://eg.hatla2ee.com/en/car/speranza/tiggo/4805174',
#  'https://eg.hatla2ee.com/en/car/bmw/320/4785041',
#  'https://eg.hatla2ee.com/en/car/jeep/cherokee/4782669',
#  'https://eg.hatla2ee.com/en/car/land-rover/Velar/4801716',
#  'https://eg.hatla2ee.com/en/car/chevrolet/pickup/4772037',
#  'https://eg.hatla2ee.com/en/car/kia/picanto/4801426',
#  'https://eg.hatla2ee.com/en/car/kia/Pegas/4761338',
#  'https://eg.hatla2ee.com/en/car/changan/v7/4801079',
#  'https://eg.hatla2ee.com/en/car/porsche/boxster/4800529',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-6/4800406',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4800414',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4805151',
#  'https://eg.hatla2ee.com/en/car/fiat/uno/4805153',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/jetta/4805148',
#  'https://eg.hatla2ee.com/en/car/peugeot/307/4805147',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/tiguan/4805138',
#  'https://eg.hatla2ee.com/en/car/citroen/c-elysee/4805136',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4805135',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-MD/4805132',
#  'https://eg.hatla2ee.com/en/car/bmw/525/4805129',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4805117',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805127',
#  'https://eg.hatla2ee.com/en/car/peugeot/3008/4805126',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804437',
#  'https://eg.hatla2ee.com/en/car/peugeot/301/4805123',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4805114',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805111',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos-2/4805108',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4802699',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4805105',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805102',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4805079',
#  'https://eg.hatla2ee.com/en/car/kia/picanto/4805097',
#  'https://eg.hatla2ee.com/en/car/speranza/tiggo/4805096',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4802706',
#  'https://eg.hatla2ee.com/en/car/renault/clio/4804631',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805085',
#  'https://eg.hatla2ee.com/en/car/fiat/polonez/4805081',
#  'https://eg.hatla2ee.com/en/car/skoda/octavia-combi/4805076',
#  'https://eg.hatla2ee.com/en/car/nissan/juke/4805075',
#  'https://eg.hatla2ee.com/en/car/kia/sorento/4803651',
#  'https://eg.hatla2ee.com/en/car/opel/Crossland/4800424',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4800441',
#  'https://eg.hatla2ee.com/en/car/nissan/urvan/4765079',
#  'https://eg.hatla2ee.com/en/car/skoda/felicia/4785101',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4799442',
#  'https://eg.hatla2ee.com/en/car/renault/sandero-step-way/4798964',
#  'https://eg.hatla2ee.com/en/car/hyundai/Accent-RB/4632422',
#  'https://eg.hatla2ee.com/en/car/renault/Kadjar/4798676',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4798689',
#  'https://eg.hatla2ee.com/en/car/renault/megane/4798705',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4805072',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4805066',
#  'https://eg.hatla2ee.com/en/car/hyundai/verna/4805064',
#  'https://eg.hatla2ee.com/en/car/peugeot/206/4805063',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4805060',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/passat/4805058',
#  'https://eg.hatla2ee.com/en/car/chevrolet/cruze/4802152',
#  'https://eg.hatla2ee.com/en/car/changan/cs-35/4804133',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805046',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4805049',
#  'https://eg.hatla2ee.com/en/car/fiat/127/4805045',
#  'https://eg.hatla2ee.com/en/car/mazda/mazda-3/4805042',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4805040',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4804214',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4805034',
#  'https://eg.hatla2ee.com/en/car/chevrolet/pickup/4805031',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4805022',
#  'https://eg.hatla2ee.com/en/car/hyundai/verna/4804395',
#  'https://eg.hatla2ee.com/en/car/land-rover/evoque/4805021',
#  'https://eg.hatla2ee.com/en/car/geely/gelly-x-pandino/4805019',
#  'https://eg.hatla2ee.com/en/car/speranza/a11/4805016',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804430',
#  'https://eg.hatla2ee.com/en/car/emgrand/ex-7/4805015',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4805013',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4805009',
#  'https://eg.hatla2ee.com/en/car/speranza/a11/4805006',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4805004',
#  'https://eg.hatla2ee.com/en/car/bmw/318/4805001',
#  'https://eg.hatla2ee.com/en/car/seat/arona/4804997',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804994',
#  'https://eg.hatla2ee.com/en/car/seat/leon/4798713',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4798726',
#  'https://eg.hatla2ee.com/en/car/chevrolet/camaro/4593846',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4798509',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4798486',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4737399',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4737351',
#  'https://eg.hatla2ee.com/en/car/seat/leon/4797127',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4796397',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4795573',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4804991',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4804989',
#  'https://eg.hatla2ee.com/en/car/peugeot/405/4804988',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804976',
#  'https://eg.hatla2ee.com/en/car/moris-garage/MG-HS/4804983',
#  'https://eg.hatla2ee.com/en/car/peugeot/5008/4804980',
#  'https://eg.hatla2ee.com/en/car/hyundai/getz/4804977',
#  'https://eg.hatla2ee.com/en/car/toyota/corona/4804974',
#  'https://eg.hatla2ee.com/en/car/kia/sorento/4804968',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4804965',
#  'https://eg.hatla2ee.com/en/car/geely/geely-x7/4804962',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804961',
#  'https://eg.hatla2ee.com/en/car/kia/sportage/4804958',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-CN7/4804956',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804953',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804950',
#  'https://eg.hatla2ee.com/en/car/hyundai/elantra/4804947',
#  'https://eg.hatla2ee.com/en/car/hyundai/elantra/4804937',
#  'https://eg.hatla2ee.com/en/car/geely/fruits/4804896',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-CN7/4804940',
#  'https://eg.hatla2ee.com/en/car/byd/f3/4804938',
#  'https://eg.hatla2ee.com/en/car/chevrolet/aveo/4804928',
#  'https://eg.hatla2ee.com/en/car/chevrolet/aveo/4804926',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804914',
#  'https://eg.hatla2ee.com/en/car/fiat/shahin/4804907',
#  'https://eg.hatla2ee.com/en/car/audi/a3/4804904',
#  'https://eg.hatla2ee.com/en/car/bmw/x1/4804902',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4804901',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804898',
#  'https://eg.hatla2ee.com/en/car/brilliance/galena/4804877',
#  'https://eg.hatla2ee.com/en/car/chevrolet/camaro/4795089',
#  'https://eg.hatla2ee.com/en/car/fiat/tipo/4795104',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4760453',
#  'https://eg.hatla2ee.com/en/car/opel/astra/4787898',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4733891',
#  'https://eg.hatla2ee.com/en/car/kia/sportage/4791873',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4791704',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4791698',
#  'https://eg.hatla2ee.com/en/car/bmw/520/4791446',
#  'https://eg.hatla2ee.com/en/car/suzuki/swift/4791368',
#  'https://eg.hatla2ee.com/en/car/brilliance/galena/4804877',
#  'https://eg.hatla2ee.com/en/car/renault/clio/4804895',
#  'https://eg.hatla2ee.com/en/car/kia/carnival/4804892',
#  'https://eg.hatla2ee.com/en/car/fiat/dogan/4804889',
#  'https://eg.hatla2ee.com/en/car/toyota/corona/4804886',
#  'https://eg.hatla2ee.com/en/car/bmw/740/4804883',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804880',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos/4804866',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/E-Golf/4804874',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804872',
#  'https://eg.hatla2ee.com/en/car/chevrolet/T-Series/4804869',
#  'https://eg.hatla2ee.com/en/car/bmw/320/4804865',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804863',
#  'https://eg.hatla2ee.com/en/car/fiat/siena/4804860',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804857',
#  'https://eg.hatla2ee.com/en/car/hyundai/matrix/4804856',
#  'https://eg.hatla2ee.com/en/car/skoda/felicia/4804848',
#  'https://eg.hatla2ee.com/en/car/bmw/316/4804844',
#  'https://eg.hatla2ee.com/en/car/fiat/shahin/4804841',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos-2/4804835',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4804833',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804826',
#  'https://eg.hatla2ee.com/en/car/isuzu/dmax/4804832',
#  'https://eg.hatla2ee.com/en/car/skoda/Octavia-A5/4804818',
#  'https://eg.hatla2ee.com/en/car/subaru/xv/4804812',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4804805',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4804802',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804799',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804797',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804793',
#  'https://eg.hatla2ee.com/en/car/nissan/qashqai/4790766',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4789223',
#  'https://eg.hatla2ee.com/en/car/mini/mini-cooper-s/4704969',
#  'https://eg.hatla2ee.com/en/car/lada/2105/4578026',
#  'https://eg.hatla2ee.com/en/car/mercedes/cla-180/4790034',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4787693',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4786383',
#  'https://eg.hatla2ee.com/en/car/opel/astra/4749570',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4786650',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4786653',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804826',
#  'https://eg.hatla2ee.com/en/car/isuzu/dmax/4804832',
#  'https://eg.hatla2ee.com/en/car/skoda/Octavia-A5/4804818',
#  'https://eg.hatla2ee.com/en/car/subaru/xv/4804812',
#  'https://eg.hatla2ee.com/en/car/hyundai/excel/4804805',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4804802',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804799',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804797',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804793',
#  'https://eg.hatla2ee.com/en/car/hyundai/Accent-RB/4804787',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4804784',
#  'https://eg.hatla2ee.com/en/car/jeep/cherokee/4804781',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4804779',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804773',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804764',
#  'https://eg.hatla2ee.com/en/car/daihatsu/terios/4804761',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4804758',
#  'https://eg.hatla2ee.com/en/car/speranza/tiggo/4804752',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4804755',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804749',
#  'https://eg.hatla2ee.com/en/car/skoda/foreman/4804737',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804736',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4804733',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n200/4804727',
#  'https://eg.hatla2ee.com/en/car/chevrolet/lanos2/4804721',
#  'https://eg.hatla2ee.com/en/car/mazda/mazda-3/4804709',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4804719',
#  'https://eg.hatla2ee.com/en/car/fiat/regata/4804718',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804716',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804715',
#  'https://eg.hatla2ee.com/en/car/nissan/sentra/4782461',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4786664',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4786400',
#  'https://eg.hatla2ee.com/en/car/land-rover/evoque/4785372',
#  'https://eg.hatla2ee.com/en/car/opel/vectra/4784918',
#  'https://eg.hatla2ee.com/en/car/kia/pride/4784526',
#  'https://eg.hatla2ee.com/en/car/toyota/C-HR/4784102',
#  'https://eg.hatla2ee.com/en/car/jeep/grand-Cherokee/4750668',
#  'https://eg.hatla2ee.com/en/car/jaguar/E-pace/4755431',
#  'https://eg.hatla2ee.com/en/car/mercedes/gla/4783779',
#  'https://eg.hatla2ee.com/en/car/volks-wagen/golf/4804712',
#  'https://eg.hatla2ee.com/en/car/daewoo/leganza/4804706',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804703',
#  'https://eg.hatla2ee.com/en/car/peugeot/405/4804701',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4804698',
#  'https://eg.hatla2ee.com/en/car/speranza/a113/4804697',
#  'https://eg.hatla2ee.com/en/car/proton/wira/4804695',
#  'https://eg.hatla2ee.com/en/car/fiat/punto-evo/4804689',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804692',
#  'https://eg.hatla2ee.com/en/car/hyundai/verna/4804691',
#  'https://eg.hatla2ee.com/en/car/jac/S4/4804686',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-AD/4804683',
#  'https://eg.hatla2ee.com/en/car/toyota/C-HR/4804680',
#  'https://eg.hatla2ee.com/en/car/kia/carens/4804679',
#  'https://eg.hatla2ee.com/en/car/opel/astra/4804676',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4804673',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4804670',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804668',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804665',
#  'https://eg.hatla2ee.com/en/car/daewoo/Nubira-2/4804664',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804659',
#  'https://eg.hatla2ee.com/en/car/skoda/felicia/4804649',
#  'https://eg.hatla2ee.com/en/car/mitsubishi/lancer/4804647',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4804644',
#  'https://eg.hatla2ee.com/en/car/geely/emgrand7/4804638',
#  'https://eg.hatla2ee.com/en/car/chevrolet/pickup/4804634',
#  'https://eg.hatla2ee.com/en/car/hyundai/getz/4804628',
#  'https://eg.hatla2ee.com/en/car/renault/sandero/4804622',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804619',
#  'https://eg.hatla2ee.com/en/car/speranza/a516/4804617',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-CN7/4782431',
#  'https://eg.hatla2ee.com/en/car/chery/Tiggo-7/4782416',
#  'https://eg.hatla2ee.com/en/car/suzuki/S-Presso/4782330',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-HD/4775066',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4775000',
#  'https://eg.hatla2ee.com/en/car/nissan/sentra/4774944',
#  'https://eg.hatla2ee.com/en/car/hyundai/Elantra-AD/4774929',
#  'https://eg.hatla2ee.com/en/car/chevrolet/optra/4774677',
#  'https://eg.hatla2ee.com/en/car/bmw/316/4774664',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4774649',
#  'https://eg.hatla2ee.com/en/car/toyota/hilux/4804599',
#  'https://eg.hatla2ee.com/en/car/mercedes/c-180/4804581',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4804593',
#  'https://eg.hatla2ee.com/en/car/honda/civic/4804590',
#  'https://eg.hatla2ee.com/en/car/suzuki/maruti/4804584',
#  'https://eg.hatla2ee.com/en/car/nissan/pick-up/4804580',
#  'https://eg.hatla2ee.com/en/car/renault/sandero-step-way/4804578',
#  'https://eg.hatla2ee.com/en/car/speranza/a516/4804575',
#  'https://eg.hatla2ee.com/en/car/zotye/SR7/4804572',
#  'https://eg.hatla2ee.com/en/car/suzuki/van/4804571',
#  'https://eg.hatla2ee.com/en/car/changan/cs-35/4804569',
#  'https://eg.hatla2ee.com/en/car/chevrolet/n300/4804566',
#  'https://eg.hatla2ee.com/en/car/mazda/323/4804563',
#  'https://eg.hatla2ee.com/en/car/byd/f3/4804550',
#  'https://eg.hatla2ee.com/en/car/renault/logan/4804556',
#  'https://eg.hatla2ee.com/en/car/moris-garage/mg-5/4804547',
#  'https://eg.hatla2ee.com/en/car/jeep/komodo/4804545',
#  'https://eg.hatla2ee.com/en/car/fiat/127/4804530',
#  'https://eg.hatla2ee.com/en/car/geely/CK2/4804542',
#  'https://eg.hatla2ee.com/en/car/hyundai/tucson/4804539',
#  'https://eg.hatla2ee.com/en/car/nissan/qashqai/4804538',
#  'https://eg.hatla2ee.com/en/car/renault/sandero-step-way/4804526',
#  'https://eg.hatla2ee.com/en/car/seat/ibiza/4804523',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4804388',
#  'https://eg.hatla2ee.com/en/car/peugeot/504/4804518',
#  'https://eg.hatla2ee.com/en/car/speranza/chery-qq/4804517',
#  'https://eg.hatla2ee.com/en/car/subaru/impreza/4802598',
#  'https://eg.hatla2ee.com/en/car/geely/CK2/4804511',
#  'https://eg.hatla2ee.com/en/car/peugeot/3008/4804509',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4804506',
#  'https://eg.hatla2ee.com/en/car/mercedes/b-200/4766102',
#  'https://eg.hatla2ee.com/en/car/nissan/sentra/4765952',
#  'https://eg.hatla2ee.com/en/car/hyundai/Tucson-Turbo/4765967',
#  'https://eg.hatla2ee.com/en/car/chery/Tiggo3/4765989',
#  'https://eg.hatla2ee.com/en/car/kia/shuma/4804388',
#  'https://eg.hatla2ee.com/en/car/peugeot/504/4804518',
#  'https://eg.hatla2ee.com/en/car/speranza/chery-qq/4804517',
#  'https://eg.hatla2ee.com/en/car/subaru/impreza/4802598',
#  'https://eg.hatla2ee.com/en/car/geely/CK2/4804511',
#  'https://eg.hatla2ee.com/en/car/peugeot/3008/4804509',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4804506',
#  'https://eg.hatla2ee.com/en/car/kia/cerato/4804505',
#  'https://eg.hatla2ee.com/en/car/mercedes/200/4802844',
#  'https://eg.hatla2ee.com/en/car/nissan/sunny/4804500',
#  'https://eg.hatla2ee.com/en/car/lada/2105/4804499',
#  'https://eg.hatla2ee.com/en/car/fiat/125/4804497',
#  'https://eg.hatla2ee.com/en/car/fiat/128/4804496',
#  'https://eg.hatla2ee.com/en/car/daewoo/lanos/4804493',
#  'https://eg.hatla2ee.com/en/car/hyundai/accent/4803332',
#  'https://eg.hatla2ee.com/en/car/toyota/corolla/4804490',
#  'https://eg.hatla2ee.com/en/car/toyota/echo/4803444',
#  'https://eg.hatla2ee.com/en/car/jeep/liberty/4804485',
#  'https://eg.hatla2ee.com/en/car/chery/Arrizo-5/4804482']

# %%
len(links)
# Out:
# 343

# %% [markdown]
# # Scrap All cars

# %%
driver = webdriver.Chrome()

# %%
def get_price():
    try:
        return driver.find_element_by_class_name('usedUnitCarPrice').text
    except:
        return np.nan

# %%
def get_main_value(car_property, main_data_dict):
    try:
        return main_data_dict[car_property]
    except:
        return np.nan

# %%
features = ['Make','Model','CC','Used since','Km','Transmission','City','Color','Body Style','Fuel','Leather seats','Closing mirrors',
           'Intelligent parking system','Sunroof','Fabric brushes','Air Conditioning','Power Steering',
           'Remote Keyless','Electric mirrors','Front Power Windows',
           'Back Power Windows','Tinted Glass','CD Player','DVD Player','Bluetooth','Multifunction'
           ,'Cassette Radio','AUX','CD Changer','USB Port','Anti - theft System','Side Airbag',
           'ABS','EPS','EBD','ESP','Sensors','Rear sensors','Driver Airbag','Passenger Airbag','Front sensors','Alloy wheels','Rear camera','GPS','Fog light','Rear spoiler',
           'Cruise control','Power Seats','Central lock','Alarm','Price']
with open('cars.csv', mode='w') as f:
    writer = csv.writer(f)
    writer.writerow(features)
    
    for i, link in enumerate(links):
        driver.get(link)
        price = get_price()
        properties = []
        values = []
        for prop in driver.find_elements_by_class_name('DescDataSubTit'):
            properties.append(prop.text)
        for val in driver.find_elements_by_class_name('DescDataVal'):
            values.append(val.text)
        main_data_dict = dict(zip(properties, values))
        make =get_main_value('Make', main_data_dict)
        model = get_main_value('Model', main_data_dict)
        CC=get_main_value('CC', main_data_dict)
        Used_since = get_main_value('Used since', main_data_dict)
        Km = get_main_value('Km', main_data_dict)
        Transmission = get_main_value('Transmission', main_data_dict)
        City = get_main_value('City', main_data_dict)
        Color = get_main_value('Color', main_data_dict)
        Body_Style = get_main_value('Body Style', main_data_dict)
        Fuel = get_main_value('Fuel', main_data_dict)
        
    
        
        
        ##
        leather_seats = 'Leather seats' in driver.page_source
        Closing_mirrors = 'Closing mirrors' in driver.page_source
        Intelligent_parking_system = 'Intelligent parking system' in driver.page_source
        Sunroof = 'Sunroof' in driver.page_source
        Fabric_brushes = 'Fabric brushes' in driver.page_source
        Air_Conditioning = 'Air Conditioning' in driver.page_source
        Power_Steering = 'Power Steering' in driver.page_source
        Remote_Keyless = 'Remote Keyless' in driver.page_source
        Electric_mirrors = 'Electric mirrors' in driver.page_source
        Front_Power_Windows = 'Front Power Windows' in driver.page_source
        Back_Power_Windows = 'Back Power Windows' in driver.page_source
        Tinted_Glass = 'Tinted Glass' in driver.page_source
        CD_Player = 'CD Player' in driver.page_source
        DVD_Player = 'DVD Player' in driver.page_source
        Bluetooth = 'Bluetooth' in driver.page_source
        Multifunction = 'Multifunction' in driver.page_source
        Cassette_Radio = 'Cassette Radio' in driver.page_source
        AUX = 'AUX' in driver.page_source
        CD_Changer = 'CD Changer' in driver.page_source
        USB_Port = 'USB Port' in driver.page_source
        
        
        Anti_theft_System = 'Anti - theft System' in driver.page_source
        Side_Airbag = 'Side Airbag' in driver.page_source
        ABS = 'ABS' in driver.page_source
        EPS = 'EPS' in driver.page_source
        EBD = 'EBD' in driver.page_source
        ESP = 'ESP' in driver.page_source
        Sensors = 'Sensors' in driver.page_source
        Rear_sensors = 'Rear sensors' in driver.page_source
        Driver_Airbag = 'Driver Airbag' in driver.page_source
        Passenger_Airbag = 'Passenger Airbag' in driver.page_source
        Front_sensors = 'Front sensors' in driver.page_source
        Alloy_wheels = 'Alloy wheels' in driver.page_source
        Rear_camera = 'Rear camera' in driver.page_source
        GPS = 'GPS' in driver.page_source
        Fog_light = 'Fog light' in driver.page_source
        Rear_spoiler = 'Rear spoiler' in driver.page_source
        Cruise_control = 'Cruise control' in driver.page_source
        Power_Seats = 'Power Seats' in driver.page_source
        Central_lock = 'Central lock' in driver.page_source
        Alarm = 'Alarm' in driver.page_source
        Price = get_price()
        print(f'[{i}] - {link}')
        writer.writerow([make,model,CC,Used_since,Km,Transmission,City,Color,Body_Style,Fuel,leather_seats,Closing_mirrors,
           Intelligent_parking_system,Sunroof,Fabric_brushes,Air_Conditioning,Power_Steering,
           Remote_Keyless,Electric_mirrors,Front_Power_Windows,
           Back_Power_Windows,Tinted_Glass,CD_Player,DVD_Player,Bluetooth,Multifunction
           ,Cassette_Radio,AUX,CD_Changer,USB_Port,Anti_theft_System,Side_Airbag
           ,ABS,EPS,EBD,ESP,Sensors,Rear_sensors,Driver_Airbag,Passenger_Airbag,
            Front_sensors,Alloy_wheels,Rear_camera,GPS,Fog_light,Rear_spoiler,
           Cruise_control,Power_Seats,Central_lock,Alarm,Price])
# Out:
# [0] - https://eg.hatla2ee.com/en/car/peugeot/3008/4804503
# [1] - https://eg.hatla2ee.com/en/car/nissan/sunny/4804046
# [2] - https://eg.hatla2ee.com/en/car/jeep/cherokee/4796227
# [3] - https://eg.hatla2ee.com/en/car/lada/granta/4787955
# [4] - https://eg.hatla2ee.com/en/car/maserati/ghibli/4803273
# [5] - https://eg.hatla2ee.com/en/car/moris-garage/mg-6/4803254
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-cf3350bed3c8> in <module>
#      11
#      12     for i, link in enumerate(links):
# ---> 13         driver.get(link)
#      14         price = get_price()
#      15         properties = []
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Anaconda3\envs\tensorflow\lib\http\client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# C:\Anaconda3\envs\tensorflow\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# C:\Anaconda3\envs\tensorflow\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# C:\Anaconda3\envs\tensorflow\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('cars.csv', encoding= 'unicode_escape')
df
# Out:
#        Make     Model       CC  Used since          Km Transmission  \
# 0   Peugeot      3008      NaN        2019   62,000 Km    automatic
# 1    Nissan     Sunny      NaN        2019   80,000 Km    automatic
# 2      Jeep  Cherokee      NaN        2011  160,000 Km    automatic
# 3      Lada    Granta  1600 CC        2020   21,500 Km    automatic
# 4  Maserati    Ghibli      NaN        2019   39,000 Km    automatic
# 5        MG         6      NaN        2022    5,000 Km          DSG
#
#                 City      Color Body Style Fuel  ...  Alloy wheels  \
# 0          6 October      Green        NaN  gas  ...          True
# 1           El Haram       Gray        NaN  gas  ...          True
# 2         Heliopolis  Champagne        NaN  gas  ...         False
# 3               Giza   Dark red      Sedan  gas  ...          True
# 4  Sheikh Zayed City      Black        NaN  gas  ...         False
# 5  Sheikh Zayed City        Red        NaN  gas  ...          True
#
#    Rear camera    GPS  Fog light  Rear spoiler  Cruise control  Power Seats  \
# 0         True  False       True         False            True         True
# 1        False  False      False         False           False        False
# 2        False  False      False         False           False        False
# 3        False  False      False         False           False        False
# 4        False  False      False         False           False        False
# 5         True  False       True         False           False        False
#
#    Central lock  Alarm          Price
# 0          True  False    600,000 EGP
# 1          True   True    255,000 EGP
# 2         False  False    365,000 EGP
# 3         False  False    185,000 EGP
# 4         False  False  1,150,000 EGP
# 5          True   True    425,000 EGP
#
# [6 rows x 51 columns]
